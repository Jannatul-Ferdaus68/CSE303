# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
df = pd.read_csv('Sales_with_NaNs_v1.3.csv')

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
df = pd.read_csv('Sales_with_NaNs_v1.3.csv')

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    ConfusionMatrixDisplay
)

# 1. Load dataset
df = pd.read_csv('Sales_with_NaNs_v1.3.csv')

# 2. Encode target
df['Purchase_Made'] = df['Purchase_Made'].map({'Yes': 1, 'No': 0})

# 3. Define features and target
features = ['Group', 'Customer_Segment', 'Sales_Before', 'Sales_After',
            'Customer_Satisfaction_Before', 'Customer_Satisfaction_After']
X = df[features]
y = df['Purchase_Made']

# ✅ 4. Drop rows with missing values
data = pd.concat([X, y], axis=1).dropna()
X = data[features]
y = data['Purchase_Made']

# 5. One-hot encode categorical features
X = pd.get_dummies(X, columns=['Group', 'Customer_Segment'])

# 6. Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 7. Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# 8. Train RBF kernel SVM
model = SVC(kernel='rbf', C=1.0, gamma=10, random_state=42)
model.fit(X_train, y_train)

# 9. Predict
y_pred = model.predict(X_test)

# 10. Evaluation metrics
print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall   :", recall_score(y_test, y_pred))
print("F1 Score :", f1_score(y_test, y_pred))

# ✅ 11. Confusion matrix
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix - RBF SVM")
plt.show()
# Out:
# Accuracy : 0.49633967789165445
# Precision: 0.5103857566765578
# Recall   : 0.49002849002849
# F1 Score : 0.5

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
df = pd.read_csv('Sales_with_NaNs_v1.3.csv')

# Encode target
df['Purchase_Made'] = df['Purchase_Made'].map({'Yes': 1, 'No': 0})

# Define features and target
features = ['Group', 'Customer_Segment', 'Sales_Before', 'Sales_After',
            'Customer_Satisfaction_Before', 'Customer_Satisfaction_After']
X = df[features]
y = df['Purchase_Made']

# Scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Sales_Before', y='Sales_After', hue='Purchase_Made', palette='Set1')
plt.title('Sales Before vs Sales After Colored by Purchase Made')
plt.xlabel('Sales Before')
plt.ylabel('Sales After')
plt.legend(title='Purchase Made')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
df = pd.read_csv('Sales_with_NaNs_v1.3.csv')

# Encode target
df['Purchase_Made'] = df['Purchase_Made'].map({'Yes': 1, 'No': 0})

# Scatter plot for customer satisfaction
plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=df,
    x='Customer_Satisfaction_Before',
    y='Customer_Satisfaction_After',
    hue='Purchase_Made',
    palette='Set1'
)
plt.title('Customer Satisfaction Before vs After (by Purchase Made)')
plt.xlabel('Customer Satisfaction Before')
plt.ylabel('Customer Satisfaction After')
plt.legend(title='Purchase Made', labels=['No', 'Yes'])
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    ConfusionMatrixDisplay
)

# 1. Load dataset
df = pd.read_csv('Sales_with_NaNs_v1.3.csv')

# 2. Encode target
df['Purchase_Made'] = df['Purchase_Made'].map({'Yes': 1, 'No': 0})

# 3. Define features and target
features = ['Group', 'Customer_Segment', 'Sales_Before', 'Sales_After',
            'Customer_Satisfaction_Before', 'Customer_Satisfaction_After']
X = df[features]
y = df['Purchase_Made']

# ✅ 4. Drop rows with any missing values (in X or y)
data = pd.concat([X, y], axis=1).dropna()
X = data[features]
y = data['Purchase_Made']

# 5. One-hot encode categorical variables
X = pd.get_dummies(X, columns=['Group', 'Customer_Segment'])

# 6. Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 7. Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# 8. Train Linear SVM
model = LinearSVC( random_state=42)
model.fit(X_train, y_train)

# 9. Predict and evaluate
y_pred = model.predict(X_test)

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall   :", recall_score(y_test, y_pred))
print("F1 Score :", f1_score(y_test, y_pred))

# ✅ 10. Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix - Linear SVM")
plt.show()
# Out:
# Accuracy : 0.5373352855051244
# Precision: 0.5482093663911846
# Recall   : 0.5669515669515669
# F1 Score : 0.5574229691876751

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    ConfusionMatrixDisplay
)

# 1. Load dataset
df = pd.read_csv('Sales_with_NaNs_v1.3.csv')

# 2. Encode target
df['Purchase_Made'] = df['Purchase_Made'].map({'Yes': 1, 'No': 0})

# 3. Define features and target
features = ['Group', 'Customer_Segment', 'Sales_Before', 'Sales_After',
            'Customer_Satisfaction_Before', 'Customer_Satisfaction_After']
X = df[features]
y = df['Purchase_Made']

# 4. Drop rows with any missing values (in X or y)
data = pd.concat([X, y], axis=1).dropna()
X = data[features]
y = data['Purchase_Made']

# 5. One-hot encode categorical variables
X = pd.get_dummies(X, columns=['Group', 'Customer_Segment'])

# 6. Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 7. Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# 8. Train Linear SVM with L1 penalty
model = LinearSVC(penalty='l1',  random_state=42)
model.fit(X_train, y_train)

# 9. Predict and evaluate
y_pred = model.predict(X_test)

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall   :", recall_score(y_test, y_pred))
print("F1 Score :", f1_score(y_test, y_pred))

# 10. Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix - Linear SVM (L1 Penalty)")
plt.show()
# Out:
# Accuracy : 0.5402635431918009
# Precision: 0.5506849315068493
# Recall   : 0.5726495726495726
# F1 Score : 0.5614525139664804

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    ConfusionMatrixDisplay
)

# 1. Load dataset
df = pd.read_csv('Sales_with_NaNs_v1.3.csv')

# 2. Encode target
df['Purchase_Made'] = df['Purchase_Made'].map({'Yes': 1, 'No': 0})

# 3. Define features and target
features = ['Group', 'Customer_Segment', 'Sales_Before', 'Sales_After',
            'Customer_Satisfaction_Before', 'Customer_Satisfaction_After']
X = df[features]
y = df['Purchase_Made']

# 4. Drop rows with any missing values (in X or y)
data = pd.concat([X, y], axis=1).dropna()
X = data[features]
y = data['Purchase_Made']

# 5. One-hot encode categorical variables
X = pd.get_dummies(X, columns=['Group', 'Customer_Segment'])

# 6. Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 7. Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# 8. Train Linear SVM with L2 penalty
model = LinearSVC(penalty='l2', random_state=42)
model.fit(X_train, y_train)

# 9. Predict and evaluate
y_pred = model.predict(X_test)

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall   :", recall_score(y_test, y_pred))
print("F1 Score :", f1_score(y_test, y_pred))

# 10. Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix - Linear SVM (L2 Penalty)")
plt.show()
# Out:
# Accuracy : 0.5373352855051244
# Precision: 0.5482093663911846
# Recall   : 0.5669515669515669
# F1 Score : 0.5574229691876751

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    ConfusionMatrixDisplay,
    classification_report
)

# 1. Load dataset
df = pd.read_csv('Sales_with_NaNs_v1.3.csv')

# 2. Encode target
df['Purchase_Made'] = df['Purchase_Made'].map({'Yes': 1, 'No': 0})

# 3. Define features and target
features = ['Group', 'Customer_Segment', 'Sales_Before', 'Sales_After',
            'Customer_Satisfaction_Before', 'Customer_Satisfaction_After']
X = df[features]
y = df['Purchase_Made']

# 4. Drop rows with any missing values (in X or y)
data = pd.concat([X, y], axis=1).dropna()
X = data[features]
y = data['Purchase_Made']

# 5. One-hot encode categorical variables
X = pd.get_dummies(X, columns=['Group', 'Customer_Segment'])

# 6. Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 7. Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# 8. Train SVM with sigmoid kernel
model = SVC(kernel='sigmoid', random_state=42)
model.fit(X_train, y_train)

# 9. Predict and evaluate
y_pred = model.predict(X_test)

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall   :", recall_score(y_test, y_pred))
print("F1 Score :", f1_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# 10. Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix - SVM with Sigmoid Kernel")
plt.show()
# Out:
# Accuracy : 0.49487554904831627
# Precision: 0.50920245398773
# Recall   : 0.47293447293447294
# F1 Score : 0.49039881831610044
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.48      0.52      0.50       332
#          1.0       0.51      0.47      0.49       351
#
#     accuracy                           0.49       683
#    macro avg       0.50      0.50      0.49       683
# weighted avg       0.50      0.49      0.49       683
